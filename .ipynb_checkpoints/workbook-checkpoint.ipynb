# %%
import pickle
import numpy as np
from random import shuffle
from agent_code.my_agent.algorithms import *
from settings import s
import time
import matplotlib.pyplot as plt
import copy
import os
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def q_gd_linapprox(next_state, prev_state_a, reward, weights, alpha, gamma):
    next_state_a = next_state[np.argmax(np.dot(next_state, weights)), :]
    weights += alpha * (reward + gamma * np.dot(next_state_a,weights) - 
                        np.dot(prev_state_a,weights)) * prev_state_a 
    return weights

# %%
def train_game(data, weights, alpha, gamma):
    for i in range(len(data)-1):
        prev_state = data[i]['state']
        prev_action = data[i]['action']
        next_state = data[i+1]['state']
        next_action = data[i+1]['action']
        
        reward = -1
        
        if data[i]['state']['step'] != 1:
            for event in data[i]['events']:
                if event == e.BOMB_DROPPED:
                    reward += 1
                elif event == e.COIN_COLLECTED:
                    reward += 100
                elif event == e.KILLED_SELF:
                    reward -= 100
                elif event == e.CRATE_DESTROYED:
                    reward += 10
                elif event == e.COIN_FOUND:
                    reward += 30
                elif event == e.KILLED_OPPONENT:
                    reward += 300
                elif event == e.GOT_KILLED:
                    reward -= 300
                elif event == e.SURVIVED_ROUND:
                    reward += 100
                elif event == e.INVALID_ACTION:
                    reward -= 2


                
        
        f0 = np.ones(6)  # for bias
        f1 = feature1(next_state) # reward good action
        f2 = feature2(next_state) # penalization bad action
        f3 = feature3(next_state)
        f4 = feature4(next_state) # reward good action
        f5 = feature5(next_state)  # penalize bad action
        f6 = feature6(next_state)  # reward good action
        f7 = feature7(next_state) # reward action
        #f8 = feature8(next_state) # rewards good action
        f9 = feature9(next_state) # rewards good action
        f10 = feature10(next_state) # rewards good action
        f11 = feature11(next_state)
        f12 = feature12(next_state)
        f13 = feature13(next_state)
        f14 = feature14(next_state)
        f15 = feature15(next_state)
        next_state = np.vstack((f0,f1,f2,f3,f4,f5,f6,f7,f9,f10,f11,f12,f13,f14,f15)).T
        
          
        f0 = np.ones(6)  # for bias
        f1 = feature1(prev_state) # reward good action
        f2 = feature2(prev_state) # penalization bad action
        f3 = feature3(prev_state)
        f4 = feature4(prev_state) # reward good action
        f5 = feature5(prev_state)  # penalize bad action
        f6 = feature6(prev_state)  # reward good action
        f7 = feature7(prev_state) # reward action
        #f8 = feature8(prev_state) # rewards good action
        f9 = feature9(prev_state) # rewards good action
        f10 = feature10(prev_state) # rewards good action
        f11 = feature11(prev_state)
        f12 = feature12(prev_state)
        f13 = feature13(prev_state)
        f14 = feature14(prev_state)
        f15 = feature15(prev_state)
        prev_state = np.vstack((f0,f1,f2,f3,f4,f5,f6,f7,f9,f10,f11,f12,f13,f14,f15)).T
        
        prev_sa = prev_state[s.actions.index(prev_action),:]
        
        new_weights = q_gd_linapprox(next_state, prev_sa, reward, 
                                     weights, alpha, gamma)
        weights = new_weights
        
        alpha = 1/data[i]['state']['step']
        #gamma = gamma**data[i]['state']['step']
        
    return weights

# %%
alpha = 0.2
gamma = 0.95
weights1 = np.ones(15)
for file in os.listdir('data-collect'):
   if file.__contains__('game_'):
        print(file)
        f = open('data-collect/'+file, 'rb')
        data = sorted(pickle.load(f), key = lambda k: k['state']['step'])
        weights1 = train_game(data, weights, alpha, gamma)
# Out:
# game_1.pickle
# game_10.pickle
# game_100.pickle
# game_101.pickle
# game_102.pickle
# game_103.pickle
# game_104.pickle
# game_105.pickle
# game_106.pickle
# game_107.pickle
# game_108.pickle
# game_109.pickle
# game_11.pickle
# game_110.pickle
# game_111.pickle
# game_112.pickle
# game_113.pickle
# game_114.pickle
# game_115.pickle
# game_116.pickle
# game_117.pickle
# game_118.pickle
# game_119.pickle
# game_12.pickle
# game_120.pickle
# game_121.pickle
# game_122.pickle
# game_123.pickle
# game_124.pickle
# game_125.pickle
# game_126.pickle
# game_127.pickle
# game_128.pickle
# game_129.pickle
# game_13.pickle
# game_130.pickle
# game_131.pickle
# game_132.pickle
# game_133.pickle
# game_134.pickle
# game_135.pickle
# game_136.pickle
# game_137.pickle
# game_138.pickle
# game_139.pickle
# game_14.pickle
# game_140.pickle
# game_141.pickle
# game_142.pickle
# game_143.pickle
# game_144.pickle
# game_145.pickle
# game_146.pickle
# game_147.pickle
# game_148.pickle
# game_149.pickle
# game_15.pickle
# game_150.pickle
# game_151.pickle
# game_152.pickle
# game_153.pickle
# game_154.pickle
# game_155.pickle
# game_156.pickle
# game_157.pickle
# game_158.pickle
# game_159.pickle
# game_16.pickle
# game_160.pickle
# game_161.pickle
# game_162.pickle
# game_163.pickle
# game_164.pickle
# game_165.pickle
# game_166.pickle
# game_167.pickle
# game_168.pickle
# game_169.pickle
# game_17.pickle
# game_170.pickle
# game_171.pickle
# game_172.pickle
# game_173.pickle
# game_174.pickle
# game_175.pickle
# game_176.pickle
# game_177.pickle
# game_178.pickle
# game_179.pickle
# game_18.pickle
# game_180.pickle
# game_181.pickle
# game_182.pickle
# game_183.pickle
# game_184.pickle
# game_185.pickle
# game_186.pickle
# game_187.pickle
# game_188.pickle
# game_189.pickle
# game_19.pickle
# game_190.pickle
# game_191.pickle
# game_192.pickle
# game_193.pickle
# game_194.pickle
# game_195.pickle
# game_196.pickle
# game_197.pickle
# game_198.pickle
# game_199.pickle
# game_2.pickle
# game_20.pickle
# game_200.pickle
# game_201.pickle
# game_202.pickle
# game_203.pickle
# game_204.pickle
# game_205.pickle
# game_206.pickle
# game_207.pickle
# game_208.pickle
# game_209.pickle
# game_21.pickle
# game_210.pickle
# game_211.pickle
# game_212.pickle
# game_213.pickle
# game_214.pickle
# game_215.pickle
# game_216.pickle
# game_217.pickle
# game_218.pickle
# game_219.pickle
# game_22.pickle
# game_220.pickle
# game_221.pickle
# game_222.pickle
# game_223.pickle
# game_224.pickle
# game_225.pickle
# game_226.pickle
# game_227.pickle
# game_228.pickle
# game_229.pickle
# game_23.pickle
# game_230.pickle
# game_231.pickle
# game_232.pickle
# game_233.pickle
# game_234.pickle
# game_235.pickle
# game_236.pickle
# game_237.pickle
# game_238.pickle
# game_239.pickle
# game_24.pickle
# game_240.pickle
# game_241.pickle
# game_242.pickle
# game_243.pickle
# game_244.pickle
# game_245.pickle
# game_246.pickle
# game_247.pickle
# game_248.pickle
# game_249.pickle
# game_25.pickle
# game_250.pickle
# game_251.pickle
# game_252.pickle
# game_253.pickle
# game_254.pickle
# game_255.pickle
# game_256.pickle
# game_257.pickle
# game_258.pickle
# game_259.pickle
# game_26.pickle
# game_260.pickle
# game_261.pickle
# game_262.pickle
# game_263.pickle
# game_264.pickle
# game_265.pickle
# game_266.pickle
# game_267.pickle
# game_268.pickle
# game_269.pickle
# game_27.pickle
# game_270.pickle
# game_271.pickle
# game_272.pickle
# game_273.pickle
# game_274.pickle
# game_275.pickle
# game_276.pickle
# game_277.pickle
# game_278.pickle
# game_279.pickle
# game_28.pickle
# game_280.pickle
# game_281.pickle
# game_282.pickle
# game_283.pickle
# game_284.pickle
# game_285.pickle
# game_286.pickle
# game_287.pickle
# game_288.pickle
# game_289.pickle
# game_29.pickle
# game_290.pickle
# game_291.pickle
# game_292.pickle
# game_293.pickle
# game_294.pickle
# game_295.pickle
# game_296.pickle
# game_297.pickle
# game_298.pickle
# game_299.pickle
# game_3.pickle
# game_30.pickle
# game_300.pickle
# game_301.pickle
# game_302.pickle
# game_303.pickle
# game_304.pickle
# game_305.pickle
# game_306.pickle
# game_307.pickle
# game_308.pickle
# game_309.pickle
# game_31.pickle
# game_310.pickle
# game_311.pickle
# game_312.pickle
# game_313.pickle
# game_314.pickle
# game_315.pickle
# game_316.pickle
# game_317.pickle
# game_318.pickle
# game_319.pickle
# game_32.pickle
# game_320.pickle
# game_321.pickle
# game_322.pickle
# game_323.pickle
# game_324.pickle
# game_325.pickle
# game_326.pickle
# game_327.pickle
# game_328.pickle
# game_329.pickle
# game_33.pickle
# game_330.pickle
# game_331.pickle
# game_332.pickle
# game_333.pickle
# game_334.pickle
# game_335.pickle
# game_336.pickle
# game_337.pickle
# game_338.pickle
# game_339.pickle
# game_34.pickle
# game_340.pickle
# game_341.pickle
# game_342.pickle
# game_343.pickle
# game_344.pickle
# game_345.pickle
# game_346.pickle
# game_347.pickle
# game_348.pickle
# game_349.pickle
# game_35.pickle
# game_350.pickle
# game_351.pickle
# game_352.pickle
# game_353.pickle
# game_354.pickle
# game_355.pickle
# game_356.pickle
# game_357.pickle
# game_358.pickle
# game_359.pickle
# game_36.pickle
# game_360.pickle
# game_361.pickle
# game_362.pickle
# game_363.pickle
# game_364.pickle
# game_365.pickle
# game_366.pickle
# game_367.pickle
# game_368.pickle
# game_369.pickle
# game_37.pickle
# game_370.pickle
# game_371.pickle
# game_372.pickle
# game_373.pickle
# game_374.pickle
# game_375.pickle
# game_376.pickle
# game_377.pickle
# game_378.pickle
# game_379.pickle
# game_38.pickle
# game_380.pickle
# game_381.pickle
# game_382.pickle
# game_383.pickle
# game_384.pickle
# game_385.pickle
# game_386.pickle
# game_387.pickle
# game_388.pickle
# game_389.pickle
# game_39.pickle
# game_390.pickle
# game_391.pickle
# game_392.pickle
# game_393.pickle
# game_394.pickle
# game_395.pickle
# game_396.pickle
# game_397.pickle
# game_398.pickle
# game_399.pickle
# game_4.pickle
# game_40.pickle
# game_400.pickle
# game_41.pickle
# game_42.pickle
# game_43.pickle
# game_44.pickle
# game_45.pickle
# game_46.pickle
# game_47.pickle
# game_48.pickle
# game_49.pickle
# game_5.pickle
# game_50.pickle
# game_51.pickle
# game_52.pickle
# game_53.pickle
# game_54.pickle
# game_55.pickle
# game_56.pickle
# game_57.pickle
# game_58.pickle
# game_59.pickle
# game_6.pickle
# game_60.pickle
# game_61.pickle
# game_62.pickle
# game_63.pickle
# game_64.pickle
# game_65.pickle
# game_66.pickle
# game_67.pickle
# game_68.pickle
# game_69.pickle
# game_7.pickle
# game_70.pickle
# game_71.pickle
# game_72.pickle
# game_73.pickle
# game_74.pickle
# game_75.pickle
# game_76.pickle
# game_77.pickle
# game_78.pickle
# game_79.pickle
# game_8.pickle
# game_80.pickle
# game_81.pickle
# game_82.pickle
# game_83.pickle
# game_84.pickle
# game_85.pickle
# game_86.pickle
# game_87.pickle
# game_88.pickle
# game_89.pickle
# game_9.pickle
# game_90.pickle
# game_91.pickle
# game_92.pickle
# game_93.pickle
# game_94.pickle
# game_95.pickle
# game_96.pickle
# game_97.pickle
# game_98.pickle
# game_99.pickle

# %%
from jupyterthemes import jtplot
jtplot.reset()

# %%
y1 = np.load('training_res/res_2/train_weights_EpsGreedy_initX.npy')
y2 = np.load('training_res/res_2/train_rewards_EpsGreedy_initX.npy')
y1 = y1.reshape(1498, 15)
x = np.arange(1498)
#y[:,1000]

plt.figure(figsize=(20, 10))
for feat in range(15):
    plt.plot(x, y1[:,feat], label='feature {}'.format(feat))
#plt.plot(x,y2)
plt.title('Feature Changes During Greedy Training with Initial Value 1')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()
print(np.load('training_res/res_2/weights_EpsGreedy_initX.npy'))
# Out:
# [-559.34570833   -0.56114572 -256.61420553 -312.05189646   -7.12338946
#   146.13308174   68.0798356  -188.0508605    11.00629559   48.91868198
#    65.90555143    1.5         -34.8793913   -43.66690559   46.3921951 ]

# %%
y1 = np.load('training_res/res_2/train_weights_Greed_initX.npy')
y2 = np.load('training_res/res_2/train_rewards_Greed_initX.npy')
y1 = y1.reshape(1500, 15)
x = np.arange(1500)
#y[:,1000]

plt.figure(figsize=(20, 10))
for feat in range(15):
    plt.plot(x, y1[:,feat], label='feature {}'.format(feat))
#plt.plot(x,y2)
plt.title('Feature Changes During Greedy Training with Handpicked Initial Value')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()
print(np.load('training_res/res_2/weights_Greed_initX.npy'))
# Out:
# [-1.79983248e+03  1.04818427e+01 -6.23323812e+02 -2.34768381e+02
#  -3.49865660e+01 -1.78611860e+02  7.60374732e+01 -3.84916802e+00
#  -7.91504659e+01 -1.04612455e+01 -1.02735595e+02  1.50000000e+00
#  -7.60963290e-02  3.79247106e+01 -3.01359196e+01]

# %%
os.listdir('training_res/res_2')
#np.load('training_res/res_2/train_rewards_EpsGreedy_initX.npy')
# Out:
# ['train_rewards_EpsGreedy_initX.npy',
#  'train_rewards_Greed_initX.npy',
#  'train_rewards_n_step_EpsGreed_initX.npy',
#  'train_rewards_n_step_Greed_initX.npy',
#  'train_weights_EpsGreedy_initX.npy',
#  'train_weights_Greed_initX.npy',
#  'train_weights_n_step_EpsGreed_initX.npy',
#  'train_weights_n_step_Greed_initX.npy',
#  'weights_EpsGreedy_initX.npy',
#  'weights_Greed_initX.npy',
#  'weights_n_step_EpsGreed_initX.npy']

# %%
y1 = np.load('training_res/res_2/train_weights_n_step_Greed_initX.npy')
y2 = np.load('training_res/res_2/train_rewards_n_step_Greed_initX.npy')
y1 = y1.reshape(1500, 15)
x = np.arange(1500)
#y[:,1000]

plt.figure(figsize=(20, 10))
for feat in range(15):
    plt.plot(x, y1[:,feat], label='feature {}'.format(feat))
#plt.plot(x,y2)
plt.title('Feature Changes During Greedy Training with Handpicked Initial Value')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()
print(np.load('training_res/res_2/weights_n_step_Greed_initX.npy'))

# %%
y = np.load('train_weights_initSA_GreedA02Y095.npy')
#len(y)
y = y.reshape(1500, 15)
x = np.arange(1500)

plt.figure(figsize=(20, 10))
for feat in range(1,15):
    plt.plot(x, y[:,feat], label='feature {}'.format(feat))

plt.title('Feature Changes During Greedy Training with Initial Value from Training simple_agent')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()

# %%
y = np.load('train_weights_init1_GreedEps025A02Y095.npy')
#len(y)
y = y.reshape(1500, 15)
x = np.arange(500)

plt.figure(figsize=(20, 10))
for feat in range(1,15):
    plt.plot(x, y[:500,feat], label='feature {}'.format(feat))

plt.title('Feature Changes During Epsilon-Greedy Training with Initial Value 1')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()

# %%
y = np.load('train_weights_initX_GreedEps025A02Y095.npy')
#len(y)
y = y.reshape(1500, 15)
x = np.arange(500)

plt.figure(figsize=(20, 10))
for feat in range(1,15):
    plt.plot(x, y[:500,feat], label='feature {}'.format(feat))

plt.title('Feature Changes During Epsilon-Greedy Training with Handpicked Initial Value')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()

# %%
y = np.load('train_weights_initRand_GreedEps025A02Y095.npy')
#len(y)
y = y.reshape(1500, 15)
x = np.arange(1500)

plt.figure(figsize=(20, 10))
for feat in range(1,15):
    plt.plot(x, y[:,feat], label='feature {}'.format(feat))

plt.title('Feature Changes During Epsilon-Greedy Training with Random Initial Value')
plt.xlabel('Episodes')
plt.ylabel('Weight Values')
plt.legend()
plt.show()
